# %% [markdown]
# # Network Intrusion Detection System

# %% [markdown]
# ## Loading Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler

columns = (['duration'
,'protocol_type'
,'service'
,'flag'
,'src_bytes'
,'dst_bytes'
,'land'
,'wrong_fragment'
,'urgent'
,'hot'
,'num_failed_logins'
,'logged_in'
,'num_compromised'
,'root_shell'
,'su_attempted'
,'num_root'
,'num_file_creations'
,'num_shells'
,'num_access_files'
,'num_outbound_cmds'
,'is_host_login'
,'is_guest_login'
,'count'
,'srv_count'
,'serror_rate'
,'srv_serror_rate'
,'rerror_rate'
,'srv_rerror_rate'
,'same_srv_rate'
,'diff_srv_rate'
,'srv_diff_host_rate'
,'dst_host_count'
,'dst_host_srv_count'
,'dst_host_same_srv_rate'
,'dst_host_diff_srv_rate'
,'dst_host_same_src_port_rate'
,'dst_host_srv_diff_host_rate'
,'dst_host_serror_rate'
,'dst_host_srv_serror_rate'
,'dst_host_rerror_rate'
,'dst_host_srv_rerror_rate'
,'attack'
,'level'])


df_train=pd.read_csv("C:\\Users\\sebin\\Desktop\\M.Tech\\S2\\Reinforcement learning\\archive\\nsl-kdd\\KDDTrain+.txt",header=None,names=columns)
df_test=pd.read_csv("C:\\Users\\sebin\\Desktop\\M.Tech\\S2\\Reinforcement learning\\archive\\nsl-kdd\\KDDTest+.txt",header=None,names=columns)

# %% [markdown]
# Data Exploration and Data Preprocessing

# %%
df_train
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 125968         0           tcp   private   S0          0          0     0
# 125969         8           udp   private   SF        105        145     0
# 125970         0           tcp      smtp   SF       2231        384     0
# 125971         0           tcp    klogin   S0          0          0     0
# 125972         0           tcp  ftp_data   SF        151          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# ...

# %% [markdown]
# ### Data Exploration

# %%
df_train.describe()
# Out:
#            duration     src_bytes     dst_bytes           land  \
# count  125973.00000  1.259730e+05  1.259730e+05  125973.000000
# mean      287.14465  4.556674e+04  1.977911e+04       0.000198
# std      2604.51531  5.870331e+06  4.021269e+06       0.014086
# min         0.00000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.00000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.00000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.00000  2.760000e+02  5.160000e+02       0.000000
# max     42908.00000  1.379964e+09  1.309937e+09       1.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125973.000000  125973.000000  125973.000000      125973.000000
# mean         0.022687       0.000111       0.204409           0.001222
# std          0.253530       0.014366       2.149968           0.045239
# min          0.000000       0.000000       0.000000           0.000000
# ...

# %%
df_train.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
df_test.isnull().sum()
# Out:
# duration                       0
# protocol_type                  0
# service                        0
# flag                           0
# src_bytes                      0
# dst_bytes                      0
# land                           0
# wrong_fragment                 0
# urgent                         0
# hot                            0
# num_failed_logins              0
# logged_in                      0
# num_compromised                0
# root_shell                     0
# su_attempted                   0
# num_root                       0
# num_file_creations             0
# num_shells                     0
# num_access_files               0
# num_outbound_cmds              0
# is_host_login                  0
# is_guest_login                 0
# count                          0
# srv_count                      0
# serror_rate                    0
# srv_serror_rate                0
# rerror_rate                    0
# srv_rerror_rate                0
# ...

# %%
df_train['attack'].value_counts()
# Out:
# normal             67343
# neptune            41214
# satan               3633
# ipsweep             3599
# portsweep           2931
# smurf               2646
# nmap                1493
# back                 956
# teardrop             892
# warezclient          890
# pod                  201
# guess_passwd          53
# buffer_overflow       30
# warezmaster           20
# land                  18
# imap                  11
# rootkit               10
# loadmodule             9
# ftp_write              8
# multihop               7
# phf                    4
# perl                   3
# spy                    2
# Name: attack, dtype: int64

# %%
df_test['attack'].value_counts()
# Out:
# normal             9711
# neptune            4657
# guess_passwd       1231
# mscan               996
# warezmaster         944
# apache2             737
# satan               735
# processtable        685
# smurf               665
# back                359
# snmpguess           331
# saint               319
# mailbomb            293
# snmpgetattack       178
# portsweep           157
# ipsweep             141
# httptunnel          133
# nmap                 73
# pod                  41
# buffer_overflow      20
# multihop             18
# named                17
# ps                   15
# sendmail             14
# rootkit              13
# xterm                13
# teardrop             12
# xlock                 9
# land                  7
# xsnoop                4
# ftp_write             3
# worm                  2
# loadmodule            2
# perl                  2
# sqlattack             2
# udpstorm              2
# phf                   2
# imap                  1
# ...

# %%
encoder = OneHotEncoder()
categorical_columns = ['protocol_type', 'service', 'flag']
encoded_features = encoder.fit_transform(df_train[categorical_columns])

scaler = StandardScaler()
numerical_columns = df_train.select_dtypes(include=['int', 'float']).columns.tolist()
scaled_features = scaler.fit_transform(df_train[numerical_columns])

# Concatenate encoded categorical features and scaled numerical features
X = np.concatenate([encoded_features.toarray(), scaled_features], axis=1)

# %%
pip install gym
# Out:
# ...
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#       --------------------------------------- 10.2/721.7 kB ? eta -:--:--
#       --------------------------------------- 10.2/721.7 kB ? eta -:--:--
#      - ----------------------------------- 30.7/721.7 kB 187.9 kB/s eta 0:00:04
#      - ----------------------------------- 30.7/721.7 kB 187.9 kB/s eta 0:00:04
#      -- ---------------------------------- 41.0/721.7 kB 178.6 kB/s eta 0:00:04
#      -- ---------------------------------- 41.0/721.7 kB 178.6 kB/s eta 0:00:04
#      --- --------------------------------- 61.4/721.7 kB 182.2 kB/s eta 0:00:04
#      --- --------------------------------- 71.7/721.7 kB 187.3 kB/s eta 0:00:04
#      --- --------------------------------- 71.7/721.7 kB 187.3 kB/s eta 0:00:04
#      ----- ------------------------------ 112.6/721.7 kB 242.7 kB/s eta 0:00:03
#      ----- ------------------------------ 112.6/721.7 kB 242.7 kB/s eta 0:00:03
# ...

# %%
import gym
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers

# Define the environment
env = gym.make('CartPole-v1')

# Define the agent
class DQNAgent:
    def __init__(self, state_size, action_size):
        pass  # Define your model architecture here
    
    def act(self, state):
        pass  # Choose action based on state
    
    def train(self, state, action, reward, next_state, done):
        pass  # Implement training logic here

# Initialize the agent
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
agent = DQNAgent(state_size, action_size)

# Training loop
for episode in range(num_episodes):
    state = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.train(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward
    
    print(f'Episode: {episode+1}, Total Reward: {total_reward}')

# Evaluate the agent
total_rewards = []
for _ in range(num_eval_episodes):
    state = env.reset()
    done = False
    total_reward = 0
    
    while not done:
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        state = next_state
        total_reward += reward
    
    total_rewards.append(total_reward)

avg_reward = np.mean(total_rewards)
print(f'Average Reward: {avg_reward}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 3
#       1 import gym
#       2 import numpy as np
# ----> 3 import tensorflow as tf
#       4 from tensorflow.keras import layers
#       6 # Define the environment
#
# ModuleNotFoundError: No module named 'tensorflow'
